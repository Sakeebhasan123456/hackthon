# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('microsoftads-performance.csv')

# %%
df
# Out:
#            Date     Campaign type  Impressions  Clicks   Cost  Conversions  \
# 0    2024-01-01  Search & content        831.0   100.0  108.6         15.0
# 1    2024-01-01          Shopping      20128.0   316.0  149.0         13.0
# 2    2024-01-02  Search & content       1069.0   163.0  188.4         26.0
# 3    2024-01-02          Shopping      31540.0   366.0  166.9         11.0
# 4    2024-01-03  Search & content        960.0   153.0  180.7         22.0
# ..          ...               ...          ...     ...    ...          ...
# 359  2024-06-28          Shopping      15266.0   229.0  129.9          8.0
# 360  2024-06-29  Search & content        365.0    87.0  133.7         15.0
# 361  2024-06-29          Shopping      14916.0   247.0  129.4         10.0
# 362  2024-06-30  Search & content        303.0    69.0   99.2         11.0
# 363  2024-06-30          Shopping      11646.0   186.0   94.3          6.0
#
#      Revenue
# 0     2240.6
# 1     2364.3
# 2     4383.0
# 3      423.6
# 4     3035.6
# ..       ...
# 359   2522.0
# 360   4178.8
# 361   1239.9
# 362   1721.7
# 363    826.3
#
# [364 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           364 non-null    object
#  1   Campaign type  364 non-null    object
#  2   Impressions    364 non-null    float64
#  3   Clicks         364 non-null    float64
#  4   Cost           364 non-null    float64
#  5   Conversions    364 non-null    float64
#  6   Revenue        364 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 20.0+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#           Date     Campaign type  Impressions  Clicks   Cost  Conversions  \
# 0   2024-01-01  Search & content        831.0   100.0  108.6         15.0
# 1   2024-01-01          Shopping      20128.0   316.0  149.0         13.0
# 2   2024-01-02  Search & content       1069.0   163.0  188.4         26.0
# 3   2024-01-02          Shopping      31540.0   366.0  166.9         11.0
# 4   2024-01-03  Search & content        960.0   153.0  180.7         22.0
# ..         ...               ...          ...     ...    ...          ...
# 359 2024-06-28          Shopping      15266.0   229.0  129.9          8.0
# 360 2024-06-29  Search & content        365.0    87.0  133.7         15.0
# 361 2024-06-29          Shopping      14916.0   247.0  129.4         10.0
# 362 2024-06-30  Search & content        303.0    69.0   99.2         11.0
# 363 2024-06-30          Shopping      11646.0   186.0   94.3          6.0
#
#      Revenue
# 0     2240.6
# 1     2364.3
# 2     4383.0
# 3      423.6
# 4     3035.6
# ..       ...
# 359   2522.0
# 360   4178.8
# 361   1239.9
# 362   1721.7
# 363    826.3
#
# [364 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Date             0
# Campaign type    0
# Impressions      0
# Clicks           0
# Cost             0
# Conversions      0
# Revenue          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                       Date   Impressions      Clicks        Cost  Conversions  \
# count                  364    364.000000  364.000000  364.000000   364.000000
# mean   2024-03-31 12:00:00  10195.065934  180.445055  139.566209    12.445055
# min    2024-01-01 00:00:00     87.000000    4.000000    9.000000     0.000000
# 25%    2024-02-15 00:00:00    763.750000  117.000000   99.900000     8.000000
# 50%    2024-03-31 12:00:00   6271.000000  160.000000  126.450000    12.000000
# 75%    2024-05-16 00:00:00  17203.250000  229.250000  165.925000    16.000000
# max    2024-06-30 00:00:00  63625.000000  675.000000  701.500000    38.000000
# std                    NaN  11446.766359  102.783571   85.522881     6.715366
#
#             Revenue
# count    364.000000
# mean    1983.526923
# min        0.000000
# 25%      769.450000
# 50%     1500.150000
# 75%     2698.400000
# max    10654.100000
# std     1725.411177

# %%
df['Date'].dt.year.unique()
# Out:
# array([2024], dtype=int32)

# %%
df
# Out:
#           Date     Campaign type  Impressions  Clicks   Cost  Conversions  \
# 0   2024-01-01  Search & content        831.0   100.0  108.6         15.0
# 1   2024-01-01          Shopping      20128.0   316.0  149.0         13.0
# 2   2024-01-02  Search & content       1069.0   163.0  188.4         26.0
# 3   2024-01-02          Shopping      31540.0   366.0  166.9         11.0
# 4   2024-01-03  Search & content        960.0   153.0  180.7         22.0
# ..         ...               ...          ...     ...    ...          ...
# 359 2024-06-28          Shopping      15266.0   229.0  129.9          8.0
# 360 2024-06-29  Search & content        365.0    87.0  133.7         15.0
# 361 2024-06-29          Shopping      14916.0   247.0  129.4         10.0
# 362 2024-06-30  Search & content        303.0    69.0   99.2         11.0
# 363 2024-06-30          Shopping      11646.0   186.0   94.3          6.0
#
#      Revenue
# 0     2240.6
# 1     2364.3
# 2     4383.0
# 3      423.6
# 4     3035.6
# ..       ...
# 359   2522.0
# 360   4178.8
# 361   1239.9
# 362   1721.7
# 363    826.3
#
# [364 rows x 7 columns]

# %%
df['profit']=df['Revenue']-df['Cost']

# %%
df['month']=df['Date'].dt.month
df=df.drop('Date',axis=1)

# %%
df
# Out:
#         Campaign type  Impressions  Clicks   Cost  Conversions  Revenue  \
# 0    Search & content        831.0   100.0  108.6         15.0   2240.6
# 1            Shopping      20128.0   316.0  149.0         13.0   2364.3
# 2    Search & content       1069.0   163.0  188.4         26.0   4383.0
# 3            Shopping      31540.0   366.0  166.9         11.0    423.6
# 4    Search & content        960.0   153.0  180.7         22.0   3035.6
# ..                ...          ...     ...    ...          ...      ...
# 359          Shopping      15266.0   229.0  129.9          8.0   2522.0
# 360  Search & content        365.0    87.0  133.7         15.0   4178.8
# 361          Shopping      14916.0   247.0  129.4         10.0   1239.9
# 362  Search & content        303.0    69.0   99.2         11.0   1721.7
# 363          Shopping      11646.0   186.0   94.3          6.0    826.3
#
#      profit  month
# 0    2132.0      1
# 1    2215.3      1
# 2    4194.6      1
# 3     256.7      1
# 4    2854.9      1
# ..      ...    ...
# 359  2392.1      6
# 360  4045.1      6
# 361  1110.5      6
# 362  1622.5      6
# 363   732.0      6
#
# [364 rows x 8 columns]

# %%
aggregated_data = df.groupby(['Campaign type']).agg({
    'Impressions': 'sum',
    'Clicks': 'sum',
    'Cost': 'sum',
    'Conversions': 'sum',
    'Revenue': 'sum',


}).reset_index()

# %%
aggregated_data
# Out:
#       Campaign type  Impressions   Clicks     Cost  Conversions   Revenue
# 0  Search & content     136673.0  20193.0  26229.9       2790.0  505865.1
# 1          Shopping    3574331.0  45489.0  24572.2       1740.0  216138.7

# %%
aggregated_data.to_csv('microsoftbudget_data.csv', index=False)

# %%
df['Cost'].sum()
# Out:
# 50802.100000000006

# %%
df['profit'].sum()
# Out:
# 671201.7

# %%
df['Revenue'].sum()
# Out:
# 722003.7999999999

# %%
total_profit = df['profit'].sum()
total_cost = df['Cost'].sum()


roi_percentage = (total_profit / total_cost) * 100

print(f'Total ROI Percentage: {roi_percentage:.2f}%')
# Out:
# Total ROI Percentage: 1321.21%

# %%
aggregated_data['Label'] = aggregated_data['Campaign type'] + ' - Month ' + aggregated_data['month'].astype(str)

# Plotting
plt.figure(figsize=(10, 10))
plt.pie(aggregated_data['profit'],
        labels=aggregated_data['Label'],
        autopct='%1.1f%%',
        startangle=90,
        colors=sns.color_palette('viridis', len(aggregated_data)))

plt.title('Aggregate Profit Distribution by Campaign Type and Month')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-269eafe4b3e3> in <cell line: 1>()
# ----> 1 aggregated_data['Label'] = aggregated_data['Campaign type'] + ' - Month ' + aggregated_data['month'].astype(str)
#       2
#       3 # Plotting
#       4 plt.figure(figsize=(10, 10))
#       5 plt.pie(aggregated_data['profit'],
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'month'

# %%
aggregated_data['Return on Conversions'] = aggregated_data['Revenue'] / aggregated_data['Conversions']


plt.figure(figsize=(8, 8))
plt.pie(aggregated_data['Return on Conversions'], labels=aggregated_data['Campaign type'], autopct='%1.1f%%', startangle=90, colors=sns.color_palette('viridis'))
plt.title('Return on Conversions by Campaign Type')
plt.show()

# %%
aggregated_data['Conversion Rate (%)'] = (aggregated_data['Conversions'] / aggregated_data['Cost']) * 100

# %%
aggregated_data
# Out:
#       Campaign type  Impressions   Clicks     Cost  Conversions   Revenue  \
# 0  Search & content     136673.0  20193.0  26229.9       2790.0  505865.1
# 1          Shopping    3574331.0  45489.0  24572.2       1740.0  216138.7
#
#    Return on Conversions  Conversion Rate (%)
# 0             181.313656            10.636716
# 1             124.217644             7.081173

# %%
average_profit_by_campaign = df.groupby('Campaign type')['profit'].sum().reset_index()


average_profit_by_campaign = average_profit_by_campaign.sort_values(by='profit', ascending=False)

print(average_profit_by_campaign)
# Out:
#       Campaign type    profit
# 0  Search & content  479635.2
# 1          Shopping  191566.5

# %%
  aggregated_data['profit']=aggregated_data['Revenue']-aggregated_data['Cost']

aggregated_data['ROI'] = (aggregated_data['profit'] / aggregated_data['Cost']) * 100
print(f'Total ROI Percentage: {roi_percentage:.2f}%')
metrics_by_campaign = aggregated_data.groupby(['Campaign type', 'month']).agg({
    'profit': 'mean',
    'ROI': 'mean'
}).reset_index()

# Sort by profit in descending order
metrics_by_campaign = metrics_by_campaign.sort_values(by='profit', ascending=False)





metrics_by_campaign
# Out:
# Total ROI Percentage: 1321.21%
#            index    profit          ROI
# 0  Campaign type  479635.2  1828.581886
# 1          month  191566.5   779.606629

# %%
aggregated_data.to_csv('microsoftbudget_data.csv', index=False)

# %%
aggregated_data
# Out:
#       Campaign type  Impressions   Clicks     Cost  Conversions   Revenue  \
# 0  Search & content     136673.0  20193.0  26229.9       2790.0  505865.1
# 1          Shopping    3574331.0  45489.0  24572.2       1740.0  216138.7
#
#    Return on Conversions  Conversion Rate (%)          ROI    profit
# 0             181.313656            10.636716  1828.581886  479635.2
# 1             124.217644             7.081173   779.606629  191566.5
